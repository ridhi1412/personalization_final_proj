# %%
import pandas as pd

# %%
ratings = pd.read_csv("../data/ratings.csv")

# %%
users_pick_top = ratings.user_id.value_counts().nlargest(50)

# %%
ratings_sample= ratings[ratings["user_id"].isin(list(users_pick_top.keys()))]
ratings_sample.count()
# Out:
# Unnamed: 0     56463
# user_id        56463
# business_id    56463
# rating         56463
# date           56463
# dtype: int64

# %%
ratings["date"] =pd.to_datetime(ratings["date"] , format='%Y-%m-%d %H:%M:%S')

# %%
latest_date=ratings.groupby(["user_id"])["date"].nlargest(1).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /media/anirudh/Data/Code/anaconda3/envs/pers/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     724             try:
# --> 725                 result = self._python_apply_general(f)
#     726             except Exception:
#
# /media/anirudh/Data/Code/anaconda3/envs/pers/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     741     def _python_apply_general(self, f):
# --> 742         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     743
#
# /media/anirudh/Data/Code/anaconda3/envs/pers/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     236             group_axes = _get_axes(group)
# --> 237             res = f(group)
# ...

# %%
atest_date=ratings.groupby(["user_id"])["date"].max().reset_index()
