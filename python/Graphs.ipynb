# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %matplotlib inline
warnings.simplefilter('ignore')

# %%
content_based = pd.read_csv('./Content_based_Metrics_tuning.csv')
dl_diffrent_files = pd.read_csv('./dl_diffrent_test_files.csv')
dl = pd.read_csv('./DL_results.csv')
lightfm_epochs = pd.read_csv('./LightFM_epochs_tune.csv')
lightfm = pd.read_csv('./LightFM_tune.csv')

# %%
display(content_based.head(2))
display(dl_diffrent_files.head(2))
display(dl.head(2))
display(lightfm_epochs.head(2))
display(lightfm.head(2))
# Out:
#    ngram_min  ngram_max  sublinear_tf  avg_overall_novelty  avg_novelty  \
# 0          1          1          True            -1.463865    -1.470062
# 1          1          1         False            -1.463869    -1.470065
#
#    avg_overall_serendipity  avg_serendipity      rmse
# 0                 0.504667         0.505666  3.222045
# 1                 0.493427         0.494620  3.221095
#           file_name       MSE  number_of_data_points
# 0  test_least_items  4.344672                    194
# 1   test_most_items  4.337076                    186
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      18.967557      0.469183         2.797795        0.073074
# 1      55.933031      0.728037         3.049085        0.054654
#
#    param_batch_size  param_epochs                            params  \
# 0               512             1  {'batch_size': 512, 'epochs': 1}
# 1               512             3  {'batch_size': 512, 'epochs': 3}
#
# ...

# %%
lightfm_epochs
# Out:
#    epochs  train_auc_mean  test_auc_mean  train_auc_std  test_auc_std  \
# 0     1.0        0.736460       0.490209       0.244904      0.394330
# 1     2.0        0.749984       0.491735       0.231093      0.393001
# 2     3.0        0.762701       0.493895       0.217256      0.392892
# 3     4.0        0.772413       0.494653       0.206100      0.393360
# 4     5.0        0.781732       0.493348       0.195503      0.392230
# 5     6.0        0.790024       0.494014       0.185550      0.393475
# 6     7.0        0.796952       0.492578       0.177978      0.392435
# 7     8.0        0.803160       0.491541       0.169684      0.394529
# 8     9.0        0.808012       0.490037       0.164245      0.393425
# 9    10.0        0.813202       0.484035       0.158651      0.392246
#
#    train_precision  test_precision  prec_at_k
# 0         0.000536        0.000473      100.0
# 1         0.000551        0.000436      100.0
# 2         0.000551        0.000443      100.0
# ...

# %%
plt.plot(lightfm_epochs['epochs'],lightfm_epochs['train_auc_mean'])
plt.plot(lightfm_epochs['epochs'],lightfm_epochs['test_auc_mean'])
plt.show()
